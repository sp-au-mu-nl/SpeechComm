# %% [markdown]
# <a href="https://colab.research.google.com/github/sp-au-mu-nl/SpeechComm/blob/main/chap01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/sp-au-mu-nl/SpeechComm/raw/refs/heads/main/data/chap01.zip
# !unzip chap01.zip
# !rm chap01.zip
# Out:
# --2025-04-23 03:47:32--  https://github.com/sp-au-mu-nl/SpeechComm/raw/refs/heads/main/data/chap01.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/sp-au-mu-nl/SpeechComm/refs/heads/main/data/chap01.zip [following]
# --2025-04-23 03:47:32--  https://raw.githubusercontent.com/sp-au-mu-nl/SpeechComm/refs/heads/main/data/chap01.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21690 (21K) [application/zip]
# Saving to: ‘chap01.zip’
#
# chap01.zip          100%[===================>]  21.18K  --.-KB/s    in 0.002s
#
# ...

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %% [markdown]
# プログラム 1.1

# %%
yA, sr = librosa.load('a8k.wav',sr=None)
tA = np.arange(0,len(yA))/sr
px.line(x=tA,y=yA)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
tA[:5]
# Out:
# array([0.      , 0.000125, 0.00025 , 0.000375, 0.0005  ])

# %%
len(tA)
# Out:
# 5665

# %%
len(yA)
# Out:
# 5665

# %%
tA[0]
# Out:
# np.float64(0.0)

# %%
tA[1]
# Out:
# np.float64(0.000125)
